# %% [markdown]
# ## Samples from SVV, PEMFC membranes
#
# ID02 (USAXS) ESRF 01/03/2022 - 03/03/2022  **SC-5103**  & 03/03/2022 - 05/03/2022 **SC-XXXX**
# **path:** /data/visitor/sc5103/id02/
# **DOI**  XXXX
# ### Setup
# **Energy =** 12.227 kEv
# **$\lambda$ =** 1.2398/12.227 = 0.1 nm
# **detx position =** from 1 to 3 m for SAXS

# %% [markdown]
# ### Sample list
#
# **membranes**
# 60/40
# 60/40 with PBI
# 80/20
# 80/20 with PBI
# 85/15
# 70/30
# Aquivion

# %% [markdown]
# ### Membranes preparation
# Cutting into pieces around 2x0.5 cm, weighting ($m_0$) and drying in vacuum for 2 hours at 150 C
#
# | sample | $m_0, g$ | $m_1, g$ | % $\Delta m_1$ |
# | -------- | ------- | ------- | ------- |
# | **60/40 (1)** | 0.02864 | 0.02485 | 0.379 |
# | **60/40 (2)** | 0.02493 | 0.02154 | 0.339 |
# | **60/40 with PBI (1)** | 0.01676 | 0.01442 | 0.234 |
# | **60/40 with PBI (2)** | 0.01667 | 0.01423 | 0.244 |
# | **80/20 (1)** | 0.02845 | 0.02432 | 0.413 |
# | **80/20 (2)** | 0.03038 | 0.02584 | 0.454 |
# | **80/20 with PBI (1)** | 0.02124 | 0.0182 | 0.304 |
# | **80/20 with PBI (2)** | 0.01720 | 0.01475 | 0.245 |
# | **85/15 (1)** | 0.02713 | 0.02282 | 0.431 |
# | **85/15 (2)** | 0.02294 | 0.01830 | 0.464 |
# | **70/30  (1)** | 0.01111 | 0.00932 | 0.181 |
# | **70/30  (2)** | 0.01209 | 0.01021 | 0.189 |
# | **Aquivion  (1)** | 0.01340 | 0.01263 | 0.077 |
# | **Aquivion  (2)** | 0.01445 | 0.01349 | 0.096 |
#
# ---

# %% [markdown]
# ### Start of balance experiment

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Sample_23_2_1

# %%
weight = [39.8, 38.4, 36.5, 35.4, 33.9, 31.7, 28.2, 25.0, 22.2, 20.3, 18.8, 16.8, 14.99, 12.9, 9.95, 8.26, 7.12, 6.28, 6.36, 8.69]
frame = [1, 5, 11, 15, 20, 29, 40, 51, 61, 68, 75, 83, 91, 100, 115, 125, 134, 144, 151,170]
plt.plot(frame, weight)
plt.show()

# %% [markdown]
# #### Sample_23_2_2

# %%
weight = [54.06, 52.7,50.7,48.1,46.93,44.96,41.68,40.3,37.8,35.25,32.92,30.8,28.96,27.6,26.46,25.16,22.78,21.35,20.5,19.56,18.58,17,15.38,13.01,11.73,9.74,9.09,8.01,7.15,6.3,5.45,4.49,3.9,3.4,2.9,2.19,1.88,1.6,1.33,0.5,0,0,0.8]
frame = [1,5,11,21,25,32,45,50,60,70,80,90,99,105,110,117,130,138,144,150,156,166,176,195,205,220,225,236,246,259,268,282,294,304,314,330,336,345,353,380,415,431,492]
plt.plot(frame, weight)
plt.show()

# %% [markdown]
# #### Sample_23_4_1

# %%
weight = [113,109,105,102.5,99.3,96.8,94.8,90.1,85.2,80.99,74.4,69.8,65.7,63.1,58.7,55,51,51.2,49.1,45.1,42.2]
frame = [1,7,13,18,23,27,31,39,49,58,72,79,83,90,97,104,111,127,132,142,150]
plt.plot(frame, weight)
plt.show()

# %%
#### Sample_23_2_2

weight = []
frame = []
plt.plot(frame, weight)
plt.show()
